# %%
import os
import pathlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import shutil
import random
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D, Activation, GlobalMaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import plot_model
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
import splitfolders

# %%
splitfolders.ratio(r"C:\Users\Ajay\Desktop\Inno_Projects\Kavi Dharshini\dataset", output="output",
    seed=1337, ratio=(.75, .2, .05), group_prefix=None, move=False)
# Out:
# Copying files: 674 files [00:00, 702.61 files/s]

# %%
data_dir = pathlib.Path('output/')
train_dir = 'output/train'
val_dir = 'output/val'
test_dir = 'output/test'

# %%
class_name = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_name)
# Out:
# ['test' 'train' 'val']

# %%
for dirpath, dirnames, filenames in os.walk('output'):
  print(f"{len(dirnames)} folder and {len(filenames)} images in {dirpath}")
# Out:
# 3 folder and 0 images in output
# 7 folder and 0 images in output\test
# 0 folder and 7 images in output\test\5_miles_speedlimit
# 0 folder and 8 images in output\test\No_Cars Allowed
# 0 folder and 4 images in output\test\No_entry
# 0 folder and 7 images in output\test\No_horn
# 0 folder and 8 images in output\test\No_Left_Turn
# 0 folder and 2 images in output\test\No_right_turn
# 0 folder and 2 images in output\test\speedlimit_15
# 7 folder and 0 images in output\train
# 0 folder and 88 images in output\train\5_miles_speedlimit
# 0 folder and 106 images in output\train\No_Cars Allowed
# 0 folder and 52 images in output\train\No_entry
# 0 folder and 97 images in output\train\No_horn
# 0 folder and 103 images in output\train\No_Left_Turn
# 0 folder and 27 images in output\train\No_right_turn
# 0 folder and 30 images in output\train\speedlimit_15
# 7 folder and 0 images in output\val
# 0 folder and 23 images in output\val\5_miles_speedlimit
# 0 folder and 28 images in output\val\No_Cars Allowed
# 0 folder and 14 images in output\val\No_entry
# 0 folder and 26 images in output\val\No_horn
# 0 folder and 27 images in output\val\No_Left_Turn
# 0 folder and 7 images in output\val\No_right_turn
# 0 folder and 8 images in output\val\speedlimit_15

# %%
def view_random_image(target_dir, target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    
    print(f"Image Shape : {img.shape}")
    plt.show()

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='5_miles_speedlimit')
# Out:
# Image Shape : (69, 80, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='No_entry')
# Out:
# Image Shape : (101, 92, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='speedlimit_15')
# Out:
# Image Shape : (78, 87, 3)

# %%
# Sets the global random seed.
tf.random.set_seed(46)

# preprocess data
train_datagen = ImageDataGenerator(rescale=1/255.0,
                                   rotation_range=0.2,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   vertical_flip=True,
                                   horizontal_flip=True)
valid_datagen = ImageDataGenerator(rescale=1/255.0)
test_datagen = ImageDataGenerator(rescale=1/255.0)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=True,
                                               seed=46)

valid_data = valid_datagen.flow_from_directory(val_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)

test_data = test_datagen.flow_from_directory(test_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)
# Out:
# Found 503 images belonging to 7 classes.
# Found 133 images belonging to 7 classes.
# Found 38 images belonging to 7 classes.

# %%
train_data.class_indices
# Out:
# {'5_miles_speedlimit': 0,
#  'No_Cars Allowed': 1,
#  'No_Left_Turn': 2,
#  'No_entry': 3,
#  'No_horn': 4,
#  'No_right_turn': 5,
#  'speedlimit_15': 6}

# %%
train_y=train_data.classes
val_y=valid_data.classes
test_y=test_data.classes

# %%
print("train_y.shape: ", train_y.shape)
print("val_y.shape: ", val_y.shape)
print("test_y.shape: ", test_y.shape)
# Out:
# train_y.shape:  (503,)
# val_y.shape:  (133,)
# test_y.shape:  (38,)

# %%
pip install albumentations
# Out:
# Collecting albumentations
#   Downloading albumentations-2.0.4-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: numpy>=1.24.4 in c:\users\ajay\anaconda3\envs\py310\lib\site-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\ajay\anaconda3\envs\py310\lib\site-packages (from albumentations) (1.14.1)
# Requirement already satisfied: PyYAML in c:\users\ajay\anaconda3\envs\py310\lib\site-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in c:\users\ajay\anaconda3\envs\py310\lib\site-packages (from albumentations) (2.10.3)
# Collecting albucore==0.0.23 (from albumentations)
#   Downloading albucore-0.0.23-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\ajay\anaconda3\envs\py310\lib\site-packages (from albumentations) (4.10.0.84)
# Collecting stringzilla>=3.10.4 (from albucore==0.0.23->albumentations)
#   Downloading stringzilla-3.11.3-cp310-cp310-win_amd64.whl.metadata (81 kB)
# Collecting simsimd>=5.9.2 (from albucore==0.0.23->albumentations)
#   Downloading simsimd-6.2.1-cp310-cp310-win_amd64.whl.metadata (67 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ajay\anaconda3\envs\py310\lib\site-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\ajay\anaconda3\envs\py310\lib\site-packages (from pydantic>=2.9.2->albumentations) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\ajay\anaconda3\envs\py310\lib\site-packages (from pydantic>=2.9.2->albumentations) (4.12.2)
# Downloading albumentations-2.0.4-py3-none-any.whl (289 kB)
# Downloading albucore-0.0.23-py3-none-any.whl (14 kB)
# Downloading simsimd-6.2.1-cp310-cp310-win_amd64.whl (86 kB)
# Downloading stringzilla-3.11.3-cp310-cp310-win_amd64.whl (80 kB)
# Installing collected packages: stringzilla, simsimd, albucore, albumentations
# Successfully installed albucore-0.0.23 albumentations-2.0.4 simsimd-6.2.1 stringzilla-3.11.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import torch
from ultralytics import YOLO
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# --------------------------- #
# 🔹 Define Paths & Parameters
# --------------------------- #
train_dir = "output/train"
val_dir = "output/val"
input_shape = (224, 224, 3)
batch_size = 32
NUM_CLASSES = 7  # Number of traffic sign classes

# --------------------------- #
# 🔹 Data Preparation (for VGG16)
# --------------------------- #
train_datagen = ImageDataGenerator(rescale=1.0/255.0)
val_datagen = ImageDataGenerator(rescale=1.0/255.0)

train_data = train_datagen.flow_from_directory(train_dir, target_size=(224, 224), 
                                               batch_size=batch_size, class_mode='categorical')
val_data = val_datagen.flow_from_directory(val_dir, target_size=(224, 224), 
                                           batch_size=batch_size, class_mode='categorical')

# --------------------------- #
# 🔹 Function to Create VGG16 Model
# --------------------------- #
def create_vgg16_model():
    base_model = VGG16(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = False  # Freeze pre-trained layers

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(256, activation="relu")(x)
    x = Dropout(0.5)(x)
    output = Dense(NUM_CLASSES, activation="softmax")(x)  # Ensure correct number of classes

    model = Model(inputs=base_model.input, outputs=output)
    return model

# --------------------------- #
# 🔹 Train and Save VGG16 Model (if not exists)
# --------------------------- #
vgg16_model_path = "vgg16_model.h5"

if not os.path.exists(vgg16_model_path):
    print("Training VGG16 Model... 🚀")
    vgg16_model = create_vgg16_model()
    vgg16_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                        loss="categorical_crossentropy",
                        metrics=["accuracy"])
    
    vgg16_model.fit(train_data, epochs=30, validation_data=val_data)
    vgg16_model.save(vgg16_model_path)
    print(f"✅ VGG16 Model saved as '{vgg16_model_path}'.")
else:
    print(f"✅ Found existing model '{vgg16_model_path}', skipping training.")

# Load the trained model
vgg16_model = create_vgg16_model()
vgg16_model.load_weights(vgg16_model_path)
print("✅ VGG16 Model Loaded Successfully!")

# --------------------------- #
# 🔹 Load YOLOv8 for Object Detection
# --------------------------- #
yolo_model = YOLO("yolov8s.pt")  # Load pre-trained YOLOv8 model

# --------------------------- #
# 🔹 Function: Preprocess Image for VGG16
# --------------------------- #
def preprocess_for_vgg16(cropped_img):
    cropped_img = cv2.resize(cropped_img, (224, 224))
    cropped_img = cropped_img.astype("float32") / 255.0
    cropped_img = np.expand_dims(cropped_img, axis=0)  # Expand dimensions for model input
    return cropped_img

# --------------------------- #
# 🔹 Function: Detect (YOLO) & Classify (VGG16)
# --------------------------- #
def detect_and_classify(image_path):
    image = cv2.imread(image_path)
    results = yolo_model(image)  # Run YOLOv8 detection

    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy()  # Get bounding boxes

        for box in boxes:
            x1, y1, x2, y2 = map(int, box)
            cropped_obj = image[y1:y2, x1:x2]  # Crop detected object

            if cropped_obj.shape[0] > 0 and cropped_obj.shape[1] > 0:
                # Preprocess cropped image for VGG16
                processed_img = preprocess_for_vgg16(cropped_obj)
                
                # Predict class using VGG16
                predictions = vgg16_model.predict(processed_img)
                class_id = np.argmax(predictions)
                confidence = predictions[0][class_id]

                # Get class labels
                class_labels = ['5_miles_speedlimit', 'No_Cars Allowed', 'No_Left_Turn', 
                                'No_entry', 'No_horn', 'No_right_turn', 'speedlimit_15']
                label = f"{class_labels[class_id]} ({confidence:.2f})"

                # Draw bounding box and classification result on image
                cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 
                            0.5, (0, 255, 0), 2)

    cv2.imshow("Detection and Classification", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# --------------------------- #
# 🔹 Run on a Test Image
# --------------------------- #
detect_and_classify(r"C:\Users\Ajay\Desktop\Inno_Projects\Kavi Dharshini\dataset\No_entry\010_1_0006.png")  # Change this to your test image path
# Out:
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 503 images belonging to 7 classes.
# Found 133 images belonging to 7 classes.
# ✅ Found existing model 'vgg16_model.h5', skipping training.
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ✅ VGG16 Model Loaded Successfully!
#
# 0: 608x640 1 traffic light, 1 stop sign, 265.3ms
# Speed: 5.0ms preprocess, 265.3ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 640)
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 182ms/step

# %%
import cv2
import torch
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from ultralytics import YOLO
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array

# ✅ Load models once
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🚀 Using device: {device}")

try:
    yolo_model = YOLO("yolov8s.pt").to(device)
    vgg16_model = tf.keras.models.load_model("vgg16_model.h5")
    print("✅ Models loaded successfully!")
except Exception as e:
    print(f"❌ Error loading models: {e}")
    raise SystemExit

# ✅ Class labels
class_labels = {
    0: '5_miles_speedlimit', 1: 'No_Cars Allowed', 2: 'No_Left_Turn',
    3: 'No_entry', 4: 'No_horn', 5: 'No_right_turn', 6: 'speedlimit_15'
}

def preprocess_for_vgg16(cropped_img):
    """ Preprocess image for VGG16 classification """
    cropped_img = cv2.resize(cropped_img, (224, 224))
    cropped_img = img_to_array(cropped_img)
    cropped_img = np.expand_dims(cropped_img, axis=0)
    cropped_img = preprocess_input(cropped_img)
    return cropped_img

def detect_and_show(image_path):
    """ Run YOLO detection and classify detected objects using VGG16 """
    image = cv2.imread(image_path)
    if image is None:
        print(f"❌ Error: Image not found at {image_path}")
        return

    print("🔍 Running YOLO object detection...")
    results = yolo_model(image)

    if not results or len(results[0].boxes) == 0:
        print("⚠️ No objects detected in the image!")
        return

    for result in results:
        for box in result.boxes.xyxy:
            x1, y1, x2, y2 = map(int, box)
            cropped_obj = image[y1:y2, x1:x2]

            if cropped_obj.shape[0] > 0 and cropped_obj.shape[1] > 0:
                processed_obj = preprocess_for_vgg16(cropped_obj)

                try:
                    predictions = vgg16_model.predict(processed_obj, verbose=0)
                    class_index = np.argmax(predictions)
                    class_name = class_labels.get(class_index, "Unknown")
                    confidence = predictions[0][class_index]

                    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    cv2.putText(image, f"{class_name} ({confidence:.2f})",
                                (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

                    print(f"✅ Detected: {class_name} (Confidence: {confidence:.2f})")
                except Exception as e:
                    print(f"❌ Error classifying object: {e}")

    # ✅ Show image with detections
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(8, 6))
    plt.imshow(image_rgb)
    plt.axis("off")
    plt.show()

# 🚀 Run
detect_and_show("C:\\Users\\Ajay\\Desktop\\Inno_Projects\\Kavi Dharshini\\dataset\\No_entry\\010_1_0006.png")
# Out:
# 0: 608x640 1 traffic light, 1 stop sign, 308.6ms
# Speed: 6.0ms preprocess, 308.6ms inference, 2.5ms postprocess per image at shape (1, 3, 608, 640)
# ✅ Detected: 5_miles_speedlimit (Confidence: 0.98)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 61
#      58     plt.show()
#      60 # 🚀 Run
# ---> 61 detect_and_show("C:\\Users\\Ajay\\Desktop\\Inno_Projects\\Kavi Dharshini\\dataset\\No_entry\\010_1_0006.png")
#
# Cell In[3], line 42, in detect_and_show(image_path)
#      40 if cropped_obj.shape[0] > 0 and cropped_obj.shape[1] > 0:
#      41     processed_obj = preprocess_for_vgg16(cropped_obj)
# ---> 42     predictions = vgg16_model.predict(processed_obj, verbose=0)
#      43     class_index = np.argmax(predictions)
#      44     class_name = class_labels.get(class_index, "Unknown")
#
# File ~\anaconda3\envs\py310\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\py310\lib\site-packages\keras\src\engine\training.py:2651, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2649     self._steps_per_execution_tuner.start()
#    2650 batch_outputs = None
# -> 2651 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2652     with data_handler.catch_stop_iteration():
#    2653         for step in data_handler.steps():
#
# File ~\anaconda3\envs\py310\lib\site-packages\keras\src\engine\data_adapter.py:1341, in DataHandler.enumerate_epochs(self)
#    1339 """Yields `(epoch, tf.data.Iterator)`."""
#    1340 with self._truncate_execution_to_epoch():
# -> 1341     data_iterator = iter(self._dataset)
#    1342     for epoch in range(self._initial_epoch, self._epochs):
#    1343         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:500, in DatasetV2.__iter__(self)
#     498 if context.executing_eagerly() or ops.inside_function():
#     499   with ops.colocate_with(self._variant_tensor):
# --> 500     return iterator_ops.OwnedIterator(self)
#     501 else:
#     502   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     503                      "iteration in eager mode or within tf.function.")
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:706, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     702   if (components is not None or element_spec is not None):
#     703     raise ValueError(
#     704         "When `dataset` is provided, `element_spec` and `components` must "
#     705         "not be specified.")
# --> 706   self._create_iterator(dataset)
#     708 self._get_next_call_count = 0
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:745, in OwnedIterator._create_iterator(self, dataset)
#     742   assert len(fulltype.args[0].args[0].args) == len(
#     743       self._flat_output_types)
#     744   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 745 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3421, in make_iterator(dataset, iterator, name)
#    3419 if tld.is_eager:
#    3420   try:
# -> 3421     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3422       _ctx, "MakeIterator", name, dataset, iterator)
#    3423     return _result
#    3424   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
base_model = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3),
                                                        include_top=False,
                                                        weights='imagenet')
base_model.trainable = False
# Out:
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
global_average_layer = GlobalAveragePooling2D()
prediction_layer = Dense(3)
softmax = Activation('softmax')

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = Dropout(0.25)(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
outputs = softmax(outputs)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  dropout (Dropout)           (None, 7, 7, 1024)        0
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 3)                 3075
#
#  activation (Activation)     (None, 3)                 0
#
# =================================================================
# Total params: 7040579 (26.86 MB)
# Trainable params: 3075 (12.01 KB)
# Non-trainable params: 7037504 (26.85 MB)
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# train model
history = model.fit(train_data, epochs=25, validation_data=valid_data)
# Out:
# Epoch 1/25
# C:\Users\ajayk\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 36s 7s/step - accuracy: 0.4834 - loss: 1.1213 - val_accuracy: 0.6889 - val_loss: 0.9695
# Epoch 2/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 6s/step - accuracy: 0.5990 - loss: 1.0155 - val_accuracy: 0.8000 - val_loss: 0.8795
# Epoch 3/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - accuracy: 0.7203 - loss: 0.8734 - val_accuracy: 0.8000 - val_loss: 0.7623
# Epoch 4/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 5s/step - accuracy: 0.7164 - loss: 0.7932 - val_accuracy: 0.8000 - val_loss: 0.6725
# Epoch 5/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - accuracy: 0.7466 - loss: 0.7175 - val_accuracy: 0.8000 - val_loss: 0.6031
# Epoch 6/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - accuracy: 0.7532 - loss: 0.6479 - val_accuracy: 0.8000 - val_loss: 0.5473
# Epoch 7/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - accuracy: 0.7627 - loss: 0.6008 - val_accuracy: 0.8222 - val_loss: 0.4998
# Epoch 8/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 5s/step - accuracy: 0.8282 - loss: 0.5267 - val_accuracy: 0.8222 - val_loss: 0.4603
# Epoch 9/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - accuracy: 0.8523 - loss: 0.4931 - val_accuracy: 0.8444 - val_loss: 0.4278
# Epoch 10/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - accuracy: 0.8356 - loss: 0.4475 - val_accuracy: 0.8667 - val_loss: 0.3963
# Epoch 11/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - accuracy: 0.8004 - loss: 0.4675 - val_accuracy: 0.8889 - val_loss: 0.3679
# Epoch 12/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.8533 - loss: 0.4242 - val_accuracy: 0.9333 - val_loss: 0.3444
# Epoch 13/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.8172 - loss: 0.4462 - val_accuracy: 0.9333 - val_loss: 0.3235
# Epoch 14/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.8884 - loss: 0.3626 - val_accuracy: 0.9333 - val_loss: 0.3051
# Epoch 15/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 15s 6s/step - accuracy: 0.9027 - loss: 0.3225 - val_accuracy: 0.9333 - val_loss: 0.2899
# Epoch 16/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.9308 - loss: 0.2876 - val_accuracy: 0.9333 - val_loss: 0.2755
# Epoch 17/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.9161 - loss: 0.2990 - val_accuracy: 0.9333 - val_loss: 0.2633
# Epoch 18/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 6s/step - accuracy: 0.9033 - loss: 0.2885 - val_accuracy: 0.9556 - val_loss: 0.2534
# Epoch 19/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.9214 - loss: 0.2754 - val_accuracy: 0.9556 - val_loss: 0.2456
# Epoch 20/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.9126 - loss: 0.2823 - val_accuracy: 0.9556 - val_loss: 0.2329
# Epoch 21/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.9579 - loss: 0.2241 - val_accuracy: 0.9556 - val_loss: 0.2217
# Epoch 22/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.9511 - loss: 0.2609 - val_accuracy: 0.9556 - val_loss: 0.2133
# Epoch 23/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.9224 - loss: 0.2519 - val_accuracy: 0.9556 - val_loss: 0.2066
# Epoch 24/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 6s/step - accuracy: 0.9322 - loss: 0.2295 - val_accuracy: 1.0000 - val_loss: 0.2012
# Epoch 25/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.9398 - loss: 0.2177 - val_accuracy: 1.0000 - val_loss: 0.1942

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(loss))

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title("Loss Curves")
  plt.xlabel("Epochs")
  plt.legend()

  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title("Accuracy Curves")
  plt.xlabel("Epochs")
  plt.legend()

# %%
plot_loss_curves(history)

# %%
val_pred = model.predict(valid_data)
val_pred = val_pred.argmax(axis=1)
print(classification_report(val_pred, val_y))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
cfm_val = confusion_matrix(val_pred, val_y)
ax = sns.heatmap(cfm_val, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
test_pred = model.predict(test_data)
test_pred = test_pred.argmax(axis=1)
print(classification_report(test_pred, test_y))
# Out:
# C:\Users\ajayk\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         2
#
#     accuracy                           1.00        13
#    macro avg       1.00      1.00      1.00        13
# weighted avg       1.00      1.00      1.00        13

# %%
cfm_test = confusion_matrix(test_pred, test_y)
ax = sns.heatmap(cfm_test, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
model.save('my_model.keras')

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ajayk\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ajayk\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = load_model('my_model.keras')

# Load the image
image_path = r"C:\Users\ajayk\Desktop\InnoProjects\Traffic_sign_detection_using_deep_learning\dataset\No_entry\010_1_0001.png"
image = image.load_img(image_path, target_size=(224, 224))

# Preprocess the image
img = np.array(image)
img = img / 255.0
img = img.reshape(1, 224, 224, 3)

# Predict the label
label = model.predict(img)

# Determine the predicted class
class_names = ['5_miles_speedlimit', 'No_entry', 'speedlimit_15']
predicted_class_index = np.argmax(label)
predicted_class = class_names[predicted_class_index]

# Print the predicted class
print("Predicted Class:", predicted_class)

# Display the image with the predicted label
plt.imshow(image)
plt.title(predicted_class)
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Predicted Class: No_entry
